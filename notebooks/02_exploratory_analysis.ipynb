# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("default")

df = pd.read_csv("../data/superstore.csv")

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
region_summary = (
    df.groupby("Region")[["Sales", "Profit"]]
    .sum()
    .sort_values(by="Profit", ascending=False)
)

region_summary
# Out:
#                Sales       Profit
# Region
# West     725457.8245  108418.4489
# East     678781.2400   91522.7800
# South    391721.9050   46749.4303
# Central  501239.8908   39706.3625

# %% [markdown]
# The West region generates the highest profit, while the Central region shows comparatively lower profitability despite substantial sales, indicating potential pricing or cost inefficiencies.

# %%
category_summary = (
    df.groupby("Category")[["Sales", "Profit"]]
    .sum()
    .sort_values(by="Profit", ascending=False)
)

category_summary
# Out:
#                        Sales       Profit
# Category
# Technology       836154.0330  145454.9481
# Office Supplies  719047.0320  122490.8008
# Furniture        741999.7953   18451.2728

# %%
subcategory_loss = (
    df.groupby("Sub-Category")["Profit"]
    .sum()
    .sort_values()
)

subcategory_loss.head(10)
# Out:
# Sub-Category
# Tables        -17725.4811
# Bookcases      -3472.5560
# Supplies       -1189.0995
# Fasteners        949.5182
# Machines        3384.7569
# Labels          5546.2540
# Art             6527.7870
# Envelopes       6964.1767
# Furnishings    13059.1436
# Appliances     18138.0054
# Name: Profit, dtype: float64

# %%
region_summary["Profit"].plot(
    kind="bar",
    title="Profit by Region",
    ylabel="Total Profit",
    xlabel="Region",
    figsize=(8,5)
)

plt.show()

# %%
category_summary.plot(
    kind="bar",
    figsize=(8,5),
    title="Sales vs Profit by Category"
)

plt.ylabel("Amount")
plt.show()

# %%
subcategory_loss.head(10).plot(
    kind="bar",
    title="Top 10 Loss-Making Sub-Categories",
    figsize=(10,5)
)

plt.ylabel("Total Loss")
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.scatter(df["Sales"], df["Profit"], alpha=0.5)
plt.title("Sales vs Profit Relationship")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.show()

# %%
df["Category"].unique()
df["Region"].value_counts()
df["Segment"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["Category"].unique()
#       2 df["Region"].value_counts()
#       3 df["Segment"].value_counts()
#
# NameError: name 'df' is not defined
